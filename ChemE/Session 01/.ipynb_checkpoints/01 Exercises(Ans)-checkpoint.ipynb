# %% [markdown]
# <p <span style="font-family:cursive; font-size:21pt""> <img src="https://s22.picofile.com/file/8449797050/MATLAB.png" width="23"/> $Vectors$ $and$ $Matrices(ANS)$</span>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Exercises 01</b>

# %%
g = 3:4:27

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Exercises 02</b>

# %%
M = [6.4:0.8:12]'

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Exercises 03</b>

# %%
N = linspace(44, 23, 7)'

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Exercises 04</b>

# %%
A = [1:7; 7:-1:1 ;linspace(2, 9, 7)]

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Exercises 05</b>

# %%
B=[linspace(4, 4, 5) linspace(5, 5, 4)]

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Exercises 06</b>

# %%
C = [linspace(6, 6, 5);linspace(8, 8, 5)]'

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Exercises 07</b>

# %%
D = [ones(3, 4) ;8:-2:2]

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Exercises 08</b>

# %%
G = [ones(3, 5);zeros(3) ones(3, 2)]

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Exercises 09</b>

# %%
a=[5 8 -1 0 2]
b=[4 1 9 -2 3]
c=[-3 5 0 6 1]

# %%
# Part (a)
D=[a(1:3) b(1:3) c(1:3)]

# %%
# Part (b)
E=[a(3:5) b(3:5) c(3:5)]'

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Exercises 10</b>

# %%
d = [6 -1 4 0 -2 5]
e = [7 5 9 0 1 3]

# %%
# Part (a)
M=[d(2:4);e(3:5);d(4:6)]

# %%
# Part (b)
N=[d(2:5)' e(3:6)']

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Exercises 11</b>

# %%
M = reshape(1:2:29, 3, 5)

# %%
# Part (a)
Va = M(3,:)

# %%
# Part (b)
Vb = M(:,4)

# %%
# Part (c)
Vc = [M(2,:) M(:,3)']

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Exercises 12</b>

# %%
N = reshape(0:3:51, 3, 6)

# %%
# Part (a)
Ua = [N(1:3) N(3, 4:6)]

# %%
# Part (b)
Ub=[N(:,1);N(:,3);N(:,6)]

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Exercises 13</b>

# %%
G=[0.1:0.1:0.7; 10:-1:4; 0:0.2:1.2; 5:-2:-7]

# %%
# Part (a)
Ma = G([1 3 4], [1 2 6 7])

# %%
# Part (b)
Mb = G([1:3], [2 4 6])

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Exercises 14</b>

# %%
K = [0.25:0.25:1.75; 2:2:14; 25:5:55]

# %%
# Part (a)
Ga = [K(:,2)' K(:,5)'; K(2,[1:6]); K(3,[2:7])]

# %%
# Part (b)
Gb = K([1 2], [3:6])

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Exercises 15</b>

# %%
# Part (a)
A = [eye(3) eye(3)]

# %%
# Part (b)
B([1 2], [4 5]) = ones(2)

# %%
# Part (c)
C = [ones(3, 1) zeros(3, 2) [ones(1); zeros(2, 1)]]

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Exercises 16</b>

# %%
A = eye(2)

# %%
B = ones(1, 2)

# %%
C = zeros(3)

# %%
D = [C [A; B]]

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Exercises 17</b>

# %%
a = [-2 5 7; 3 -6 2; 9 -3 8];
b = [-17.5; 40.6; 56.2];
x = a\b

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Exercises 18</b>

# %%
a = [2 -4 5 -3.5 1.8 4;
    -1.5 3 4 -1 -2 5;
     5 1 -6 3 -2 2;
     1.2 -2 3 4 -1 4;
     4 1 -2 -3 -4 1.5;
     3 1 -1 4 -2 -4]
b = [52.52; -21.1; -27.6; 9.16; -17.9; -16.2]
x = a\b

# %% [markdown]
# <img src="https://s23.picofile.com/file/8449797826/celebrate.png" alt="notebook" width=200 align="center" />

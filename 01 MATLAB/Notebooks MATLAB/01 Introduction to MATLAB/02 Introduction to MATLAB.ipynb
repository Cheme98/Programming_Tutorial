# %% [markdown]
# <img src="../../../images/banners/01 pic.png" alt="if-block" width=600 align="center" />

# %% [markdown]
# ## <img src="https://s22.picofile.com/file/8449797050/MATLAB.png" width="23"/> $Introduction$ $to$ $MATLAB$ $(ANS)$

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Exercises 01</b>

# %%
# Part (A):
# Part (B):
# Part (C):
# Part (D):
# Part (E):
# Part (F):
# Part (G):
# Part (H):

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Exercises 02</b>

# %%
# Part (A):
# Part (B):
# Part (C):
# Part (D):
# Part (E):
# Part (F):

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Exercises 03</b>

# %%
alpha = pi/8; beta = pi/6;
Left = tan(alpha + beta)
Right = (tan(alpha) + tan(beta))/(1 - tan(alpha)*tan(beta))

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Exercises 04</b>

# %%
xa = pi/6; xb = pi/3;
Ia = 2*xa*cos(xa) + (xa^2-2)*sin(xa)
Ib = 2*xb*cos(xb) + (xb^2-2)*sin(xb)
I = Ib - Ia

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Exercises 05</b>

# %%
a = 8; h = 13;
L = sqrt(a^2 + 4*h^2) + a^2*log(2*h/a + sqrt((2*h/a)^2 + 1))/(2*h)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Exercises 06</b>

# %%
ri = 1.25/2; ro = 2.25/2; h = 2;
Vcon = pi*h/3*(ri^2 + ri*ro + ro^2);
Vtop = 2*pi*ro^3;
V = Vcon + Vtop

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Exercises 07</b>

# %%
4217 - fix(4217/36)*36

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Exercises 08</b>

# %%
nBuses=fix(777/46)
nVans=ceil(nPeoLeft/12)
nSeatEmp=nVans*12 - nPeoLeft

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Exercises 09</b>

# %%
format short
V = 15; R1 = 119.8; R2 = 120.5; R3 = 121.2; R4 = 119.3;
c = R2/R1; d = R3/R4;
Vab = V*(c - d)/((c + 1)*(d + 1))

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Exercises 10</b>

# %%
V = 80; R = 6; f = 50; L = 400E-3; C = 40E-6;
w = 2*pi*f;
I = V/sqrt(R^2 + (w*L - 1/(w*C))^2)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Exercises 11</b>

# %%
# Part (a):
n=26; r=6;
P=factorial(n)/factorial(n-r)

# %%
# Part (a):
n=26; r=6;
P=factorial(n)/factorial(n-r)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Exercises 12</b>

# %%
n = 19;
nApp = sqrt((2*n + 1/3)*pi)*n^n*exp(-n)
nTru = factorial(n)
Error = (nTru - nApp)/nTru

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Exercises 13</b>

# %%
G = 6.67E-11; dS_E = 149.6E9; dM_E = 384.4E6;
mE = 5.98E28; mS = 2E30; mM = 7.36E22;
FSE = G * mS * mE/ dS_E^2;
FME = G * mM * mE/ dM_E^2;
Ratio = round(FSE/FME)

# %% [markdown]
# <img src="https://s23.picofile.com/file/8449797826/celebrate.png" alt="notebook" width=200 align="center" />
